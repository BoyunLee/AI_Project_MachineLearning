# %%
import pandas as pd
import mariadb
from sqlalchemy import create_engine

# 실행 안되면 --> host를 127.0.0.1 

conn  = mariadb.connect(
    user='team3', 
    password='dbdb', 
    database='team3db', 
    host='210.119.12.121',
    port=3306
)

# 위 커넥션 정보와 동일하게 입력
engine = create_engine("mysql://{user}:{pw}@{host}/{db}".format(user='team3', pw='dbdb',host='210.119.12.121', db='team3db'))

# %%
select_sql = "SELECT * FROM train"

# %%
train_df = pd.read_sql_query(select_sql, engine,index_col='index')
train_df
# Out:
#            SAMPLE_ID ARI_CO ARI_PO SHIP_TYPE_CATEGORY       DIST  \
# index
# 0       TRAIN_000000     SG   GIW5          Container  30.881018
# 1       TRAIN_000001     IN   UJM2               Bulk   0.000000
# 2       TRAIN_000002     CN   EUC8          Container   0.000000
# 3       TRAIN_000003     JP   ZAG4          Container   0.000000
# 4       TRAIN_000004     SG   GIW5          Container  27.037650
# ...              ...    ...    ...                ...        ...
# 391928  TRAIN_391934     JP   QYY1          Container   0.000000
# 391929  TRAIN_391935     SG   GIW5               Bulk   5.884603
# 391930  TRAIN_391936     US   QGN3               Bulk  70.660241
# 391931  TRAIN_391937     TW   JWI3          Container   9.448179
# 391932  TRAIN_391938     TW   JWI3          Container   0.000000
#
#                      ATA       ID  BREADTH  BUILT  DEADWEIGHT  ...  LENGTH  \
# index                                                          ...
# 0       2018-12-17 21:29  Z618338     30.0     24       24300  ...   180.0
# 1        2014-09-23 6:59  X886125     30.0     13       35900  ...   180.0
# 2       2015-02-03 22:00  T674582     50.0     12      146000  ...   370.0
# 3        2020-01-17 4:02  Y847238     20.0     18        6910  ...   120.0
# 4        2020-01-26 7:51  A872328     50.0     10      116000  ...   300.0
# ...                  ...      ...      ...    ...         ...  ...     ...
# 391928   2017-06-06 5:02  Y375615     20.0     27        6820  ...   110.0
# 391929   2019-10-16 0:36  K635567     10.0     12        3160  ...    80.0
# 391930  2021-03-23 22:35  J284147     30.0      8       60300  ...   200.0
# 391931   2015-01-08 7:15  J644215     30.0     29       23800  ...   170.0
# 391932  2015-06-08 23:30  D123358     30.0     15       50600  ...   260.0
#
#         SHIPMANAGER                         FLAG    U_WIND    V_WIND  \
# index
# 0            CQSB78                       Panama -0.527582 -0.075277
# 1            SPNO34             Marshall Islands  2.244962  0.213273
# 2            FNPK22                        Malta -1.050854 -0.122173
# 3            PBZV77                      Bahamas -3.180000 -1.610000
# 4            GUCE76                      Liberia -0.330000 -3.280000
# ...             ...                          ...       ...       ...
# 391928       KEJZ24  China, People's Republic Of  0.836331 -0.767929
# 391929       JLTM64                      Vietnam -0.660000  0.970000
# 391930       YERJ68                    Singapore -3.440000  7.990000
# 391931       HCZK58                      Comoros -0.996649 -0.826293
# 391932       GRJG55             Hong Kong, China -0.996649 -0.826293
#
#        AIR_TEMPERATURE        BN  ATA_LT  PORT_SIZE     CI_HOUR
# index
# 0            27.637513  2.014493       5   0.002615    3.450000
# 1            28.263135  3.102933      12   0.000217    0.000000
# 2            17.651842  3.210685       6   0.001614    0.000000
# 3             6.700000  2.629350      13   0.000356    0.000000
# 4            25.600000  2.495953      15   0.002615  253.554444
# ...                ...       ...     ...        ...         ...
# 391928       17.033054  2.157586      14   0.000552    0.000000
# 391929       27.300000  1.253491       8   0.002615  144.061389
# 391930       21.100000  4.766257      18   0.000155   41.482222
# 391931       25.702965  2.987039      15   0.000990    7.485278
# 391932       25.702965  2.987039       7   0.000990    0.000000
#
# [391933 rows x 23 columns]

# %%
df2 = pd.read_csv('./data/test.csv')
df2.to_sql('test',engine, if_exists='replace', chunksize=1000 )
# Out:
# 220491

# %%
test_df = pd.read_sql_query('SELECT * FROM test', engine,index_col='index')
test_df
# Out:
#           SAMPLE_ID ARI_CO ARI_PO SHIP_TYPE_CATEGORY        DIST  \
# index
# 0       TEST_000000     SG   GIW5          Container    1.826589
# 1       TEST_000001     CN   WEY7              Cargo   25.399386
# 2       TEST_000002     CN   NGG6          Container  111.079467
# 3       TEST_000003     CA   FFM2               Bulk    9.175258
# 4       TEST_000004     JP   QYY1          Container    0.000000
# ...             ...    ...    ...                ...         ...
# 220486  TEST_220486     BR   TMW2               Bulk   21.712733
# 220487  TEST_220487     CA   GRQ5               Bulk    4.870490
# 220488  TEST_220488     JP   VYJ1             Tanker   17.068286
# 220489  TEST_220489     CN   QQW1              Cargo    0.000000
# 220490  TEST_220490     MZ   PAF4          Container   32.280098
#
#                      ATA       ID  BREADTH  BUILT  DEADWEIGHT  ...      GT  \
# index                                                          ...
# 0       2020-06-18 11:58  K322654     50.0     18      117000  ...  109000
# 1       2021-05-26 22:20  E376681     10.0     13        3810  ...    2560
# 2        2019-12-16 0:09  F811111     20.0     26       10900  ...    8440
# 3        2015-11-16 5:30  A737561     30.0      9       55800  ...   31500
# 4        2018-10-24 1:11  A827175     30.0     19       39800  ...   33000
# ...                  ...      ...      ...    ...         ...  ...     ...
# 220486  2017-04-04 15:53  E731427     60.0     15      298000  ...  151000
# 220487  2016-08-22 16:22  Q434522     30.0      9       80500  ...   42700
# 220488  2022-07-10 14:53  U148516     10.0     14        1200  ...     500
# 220489  2020-12-28 14:38  C235264     10.0     27        3420  ...    2000
# 220490   2015-11-07 6:34  N282778     30.0     35       41800  ...   31400
#
#         LENGTH  SHIPMANAGER       FLAG U_WIND V_WIND  AIR_TEMPERATURE  \
# index
# 0        340.0       KQMD74     Panama   0.37   1.63             27.1
# 1         80.0       LBYS27     Belize  -2.79  -2.33             14.2
# 2        140.0       EKFV15  Singapore   0.04  -4.91              9.3
# 3        190.0       MASW32     Panama    NaN    NaN              NaN
# 4        220.0       SIEL54    Liberia    NaN    NaN              NaN
# ...        ...          ...        ...    ...    ...              ...
# 220486   330.0       UWHE18      Japan    NaN    NaN              NaN
# 220487   220.0       BBXV46    Liberia    NaN    NaN              NaN
# 220488    60.0       DYUA26      Japan  -2.87   1.22             27.4
# 220489    80.0       VKVS56     Belize  -2.65  -0.64              8.2
# 220490   200.0       TQXV21     Panama    NaN    NaN              NaN
#
#               BN  ATA_LT  PORT_SIZE
# index
# 0       1.587063      19   0.002615
# 1       2.663972       6   0.001028
# 2       3.255315       8   0.001743
# 3            NaN       2   0.000182
# 4            NaN      10   0.000552
# ...          ...     ...        ...
# 220486       NaN      13   0.000080
# 220487       NaN      13   0.000039
# 220488  2.405268      23   0.000264
# 220489  2.199039      22   0.000595
# 220490       NaN       8   0.000054
#
# [220491 rows x 22 columns]
